# %% [markdown]
# # Simulated Annealing for Feature Selection
# ## 04 - Simulated Annealing Algorithm (Actual Demo Run)
# ___

# %%
import sys
#sys.path.append(r'C:\Users\fakep\Documents\S3 ITS\Machine Learning with Python\Simulated-Annealing-Feature-Selection-main\src')
sys.path.append(r'C:\Users\hendr\Documents\S3 ITS\Machine Learning with Python\MachineLearning\Simulated-Annealing-Feature-Selection-main\src')

from main import simulated_annealing
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 5>()
#       2 #sys.path.append(r'C:\Users\fakep\Documents\S3 ITS\Machine Learning with Python\Simulated-Annealing-Feature-Selection-main\src')
#       3 sys.path.append(r'C:\Users\hendr\Documents\S3 ITS\Machine Learning with Python\MachineLearning\Simulated-Annealing-Feature-Selection-main\src')
# ----> 5 from main import simulated_annealing
#
# ModuleNotFoundError: No module named 'main'

# %%
from main import simulated_annealing

# %%
import pandas as pd
import time  
import pandas as pd
import numpy as np
import random
from datetime import datetime as dt
from utils import train_model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 7>()
#       5 import random
#       6 from datetime import datetime as dt
# ----> 7 from utils import train_model
#
# ModuleNotFoundError: No module named 'utils'

# %%
# Load data
#df = pd.read_csv(r'C:\Users\fakep\Documents\S3 ITS\Machine Learning with Python\Simulated-Annealing-Feature-Selection-main\data\churn2.csv')
df = pd.read_csv(r'C:\Users\hendr\Documents\S3 ITS\Machine Learning with Python\MachineLearning\Simulated-Annealing-Feature-Selection-main\data\churn2.csv')
# Drop the first column
df = df.iloc[:, 1:]


# Assuming the target variable is named 'target' and all others are features
X_train = df.drop(columns=['churn'])
y_train = df['churn']

# %%
df.head()
# Out:
#    state  account length  area code  international plan  voice mail plan  \
# 0     16             128        415                   0                1
# 1     35             107        415                   0                1
# 2     31             137        415                   0                0
# 3     35              84        408                   1                0
# 4     36              75        415                   1                0
#
#    number vmail messages  total day minutes  total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    total day charge  total eve minutes  total eve calls  total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    customer service calls  churn
# 0                       1      0
# 1                       1      0
# 2                       0      0
# 3                       2      0
# 4                       3      0

# %%
results, best_metric, best_subset_cols = simulated_annealing(X_train, y_train)

# %%
results

# %%
best_metric

# %%
best_subset_cols

# %%
# Multiple Runs for Robustness Testing
num_runs = 10  # Number of runs
run_times = []
all_metrics = []
selected_features_count = []


classifier_name = "KNN"
fitness_function = "accuracy"


for run in range(num_runs):
    print(f"Starting Run {run + 1}")
    
    # Start the timer for the run
    start_time = time.time()
    
    # Run the simulated annealing process
    results, best_metric, best_subset_cols = simulated_annealing(X_train, y_train, classifier_name, fitness_function, run_index=run+1)
    
    # End the timer for the run
    end_time = time.time()
    
    # Calculate the run time and store it
    run_time = end_time - start_time
    run_times.append(run_time)
    
    print(f"Run {run + 1} completed in {run_time:.2f} seconds")
    
    
    #store the best metric from this run
    all_metrics.append(best_metric)
    # Optionally store the results
    # all_results.append((results, best_metric, best_subset_cols))
    
    # Store the number of features selected in this run
    selected_features_count.append(len(best_subset_cols))
    

# After all runs are complete
mean_runtime = np.mean(run_times)
std_runtime = np.std(run_times)

print(f"Average run time over {num_runs} runs: {mean_runtime:.2f} seconds")
print(f"Standard deviation of run time: {std_runtime:.2f} seconds")

# Calculate average and standard deviation of each metric
avg_metrics = {key: np.mean([metric[key] for metric in all_metrics]) for key in all_metrics[0]}
std_metrics = {key: np.std([metric[key] for metric in all_metrics]) for key in all_metrics[0]}

# Display average and standard deviation of metrics
print("\nAverage Metrics over all runs:")
for metric, value in avg_metrics.items():
    print(f"{metric}: {value:.3f}")

print("\nStandard Deviation of Metrics over all runs:")
for metric, value in std_metrics.items():
    print(f"{metric}: {value:.3f}")

# Display the best metrics for each run
print("\nBest Metrics from each run:")
for run_index, metrics in enumerate(all_metrics):
    print(f"Run {run_index + 1}:")
    for metric, value in metrics.items():
        print(f"  {metric}: {value:.3f}")

# Calculate and display the average number of features selected
average_features_selected = np.mean(selected_features_count)
print(f"\nAverage number of features selected over {num_runs} runs: {average_features_selected:.2f}")
# Out:
# Starting Run 1
# Starting Iteration 1
# Worse Fitness but accepted. Fitness change: 0.0000, Acceptance probability: 1.0000, Random number: 0.5904
# Starting Iteration 2
# Improvement in Fitness from 0.1439 to 0.1423 - New subset accepted
# Starting Iteration 3
# Improvement in Fitness from 0.1423 to 0.1414 - New subset accepted
# Starting Iteration 4
# Improvement in Fitness from 0.1414 to 0.1398 - New subset accepted
# Starting Iteration 5
# Worse Fitness but accepted. Fitness change: 0.0050, Acceptance probability: 0.9998, Random number: 0.6538
# Starting Iteration 6
# Improvement in Fitness from 0.1398 to 0.1354 - New subset accepted
# Starting Iteration 7
# Worse Fitness but accepted. Fitness change: 0.0104, Acceptance probability: 0.9996, Random number: 0.1707
# Starting Iteration 8
# Worse Fitness but accepted. Fitness change: 0.0010, Acceptance probability: 1.0000, Random number: 0.0878
# Starting Iteration 9
# Worse Fitness but accepted. Fitness change: 0.0015, Acceptance probability: 0.9999, Random number: 0.3977
# Starting Iteration 10
# Improvement in Fitness from 0.1354 to 0.1309 - New subset accepted
# Starting Iteration 11
# Improvement in Fitness from 0.1309 to 0.1289 - New subset accepted
# Starting Iteration 12
# Worse Fitness but accepted. Fitness change: 0.0025, Acceptance probability: 0.9999, Random number: 0.9569
# Starting Iteration 13
# Worse Fitness but accepted. Fitness change: 0.0040, Acceptance probability: 0.9997, Random number: 0.5443
# Starting Iteration 14
# Worse Fitness but accepted. Fitness change: 0.0045, Acceptance probability: 0.9997, Random number: 0.6656
# Starting Iteration 15
# Worse Fitness but accepted. Fitness change: 0.0040, Acceptance probability: 0.9997, Random number: 0.6150
# Starting Iteration 16
# Worse Fitness but accepted. Fitness change: 0.0025, Acceptance probability: 0.9998, Random number: 0.7019
# Starting Iteration 17
# Worse Fitness but accepted. Fitness change: 0.0030, Acceptance probability: 0.9998, Random number: 0.1087
# Starting Iteration 18
# Improvement in Fitness from 0.1289 to 0.1175 - New subset accepted
# Starting Iteration 19
# Worse Fitness but accepted. Fitness change: 0.0024, Acceptance probability: 0.9998, Random number: 0.8390
# Starting Iteration 20
# Improvement in Fitness from 0.1175 to 0.1105 - New subset accepted
# Starting Iteration 21
# Worse Fitness but accepted. Fitness change: 0.0436, Acceptance probability: 0.9951, Random number: 0.9411
# Starting Iteration 22
# Worse Fitness but accepted. Fitness change: 0.0539, Acceptance probability: 0.9935, Random number: 0.7986
# Starting Iteration 23
# Worse Fitness but accepted. Fitness change: 0.0564, Acceptance probability: 0.9927, Random number: 0.5846
# Starting Iteration 24
# Worse Fitness but accepted. Fitness change: 0.0515, Acceptance probability: 0.9928, Random number: 0.2929
# Starting Iteration 25
# Worse Fitness but accepted. Fitness change: 0.0490, Acceptance probability: 0.9927, Random number: 0.9115
# Starting Iteration 26
# Worse Fitness but accepted. Fitness change: 0.0539, Acceptance probability: 0.9913, Random number: 0.2726
# Starting Iteration 27
# Worse Fitness but accepted. Fitness change: 0.0574, Acceptance probability: 0.9901, Random number: 0.0063
# Starting Iteration 28
# Worse Fitness but accepted. Fitness change: 0.0569, Acceptance probability: 0.9894, Random number: 0.1200
# Starting Iteration 29
# Worse Fitness but accepted. Fitness change: 0.0554, Acceptance probability: 0.9889, Random number: 0.3350
# Starting Iteration 30
# Worse Fitness but accepted. Fitness change: 0.0539, Acceptance probability: 0.9884, Random number: 0.0765
# Starting Iteration 31
# Worse Fitness but accepted. Fitness change: 0.0529, Acceptance probability: 0.9878, Random number: 0.3972
# Starting Iteration 32
# Worse Fitness but accepted. Fitness change: 0.0505, Acceptance probability: 0.9875, Random number: 0.6954
# Starting Iteration 33
# Worse Fitness but accepted. Fitness change: 0.0525, Acceptance probability: 0.9860, Random number: 0.7913
# Starting Iteration 34
# Worse Fitness but accepted. Fitness change: 0.0525, Acceptance probability: 0.9850, Random number: 0.1727
# Starting Iteration 35
# Worse Fitness but accepted. Fitness change: 0.0495, Acceptance probability: 0.9848, Random number: 0.0940
# Starting Iteration 36
# Worse Fitness but accepted. Fitness change: 0.0465, Acceptance probability: 0.9846, Random number: 0.2306
# Starting Iteration 37
# Worse Fitness but accepted. Fitness change: 0.0529, Acceptance probability: 0.9812, Random number: 0.8206
# Starting Iteration 38
# Worse Fitness but accepted. Fitness change: 0.0535, Acceptance probability: 0.9796, Random number: 0.5176
# Starting Iteration 39
# Worse Fitness but accepted. Fitness change: 0.0545, Acceptance probability: 0.9777, Random number: 0.1259
# Starting Iteration 40
# Worse Fitness but accepted. Fitness change: 0.0366, Acceptance probability: 0.9838, Random number: 0.2550
# Starting Iteration 41
# Worse Fitness but accepted. Fitness change: 0.0401, Acceptance probability: 0.9810, Random number: 0.5716
# Starting Iteration 42
# Worse Fitness but accepted. Fitness change: 0.0351, Acceptance probability: 0.9821, Random number: 0.5758
# Starting Iteration 43
# Worse Fitness but accepted. Fitness change: 0.0252, Acceptance probability: 0.9861, Random number: 0.1740
# Starting Iteration 44
# Worse Fitness but accepted. Fitness change: 0.0252, Acceptance probability: 0.9851, Random number: 0.6932
# Starting Iteration 45
# Worse Fitness but accepted. Fitness change: 0.0385, Acceptance probability: 0.9756, Random number: 0.2276
# Starting Iteration 46
# Worse Fitness but accepted. Fitness change: 0.0475, Acceptance probability: 0.9678, Random number: 0.6554
# Starting Iteration 47
# Worse Fitness but accepted. Fitness change: 0.0554, Acceptance probability: 0.9598, Random number: 0.7206
# Starting Iteration 48
# Worse Fitness but accepted. Fitness change: 0.0469, Acceptance probability: 0.9633, Random number: 0.6259
# Starting Iteration 49
# Worse Fitness but accepted. Fitness change: 0.0351, Acceptance probability: 0.9704, Random number: 0.0292
# Starting Iteration 50
# Worse Fitness but accepted. Fitness change: 0.0306, Acceptance probability: 0.9722, Random number: 0.9368
# Run 1 completed in 15.94 seconds
# Starting Run 2
# Starting Iteration 1
# Improvement in Fitness from 0.1399 to 0.1394 - New subset accepted
# Starting Iteration 2
# Improvement in Fitness from 0.1394 to 0.1319 - New subset accepted
# Starting Iteration 3
# Improvement in Fitness from 0.1319 to 0.1191 - New subset accepted
# Starting Iteration 4
# Worse Fitness but accepted. Fitness change: 0.0470, Acceptance probability: 0.9985, Random number: 0.4489
# Starting Iteration 5
# Worse Fitness but accepted. Fitness change: 0.0475, Acceptance probability: 0.9983, Random number: 0.1249
# Starting Iteration 6
# Worse Fitness but accepted. Fitness change: 0.0475, Acceptance probability: 0.9982, Random number: 0.3137
# Starting Iteration 7
# Worse Fitness but accepted. Fitness change: 0.0500, Acceptance probability: 0.9980, Random number: 0.0492
# Starting Iteration 8
# Worse Fitness but accepted. Fitness change: 0.0045, Acceptance probability: 0.9998, Random number: 0.8987
# Starting Iteration 9
# Worse Fitness but accepted. Fitness change: 0.0089, Acceptance probability: 0.9996, Random number: 0.8465
# Starting Iteration 10
# Worse Fitness but accepted. Fitness change: 0.0436, Acceptance probability: 0.9978, Random number: 0.1305
# Starting Iteration 11
# Worse Fitness but accepted. Fitness change: 0.0465, Acceptance probability: 0.9975, Random number: 0.8828
# Starting Iteration 12
# Worse Fitness but accepted. Fitness change: 0.0441, Acceptance probability: 0.9974, Random number: 0.5562
# Starting Iteration 13
# Worse Fitness but accepted. Fitness change: 0.0475, Acceptance probability: 0.9970, Random number: 0.3874
# Starting Iteration 14
# Worse Fitness but accepted. Fitness change: 0.0470, Acceptance probability: 0.9968, Random number: 0.8129
# Starting Iteration 15
# Worse Fitness but accepted. Fitness change: 0.0445, Acceptance probability: 0.9968, Random number: 0.2474
# Starting Iteration 16
# Worse Fitness but accepted. Fitness change: 0.0440, Acceptance probability: 0.9966, Random number: 0.3168
# Starting Iteration 17
# Worse Fitness but accepted. Fitness change: 0.0475, Acceptance probability: 0.9960, Random number: 0.4768
# Starting Iteration 18
# Worse Fitness but accepted. Fitness change: 0.0500, Acceptance probability: 0.9955, Random number: 0.9286
# Starting Iteration 19
# Worse Fitness but accepted. Fitness change: 0.0465, Acceptance probability: 0.9955, Random number: 0.7196
# Starting Iteration 20
# Worse Fitness but accepted. Fitness change: 0.0273, Acceptance probability: 0.9972, Random number: 0.0915
# Starting Iteration 21
# Worse Fitness but accepted. Fitness change: 0.0198, Acceptance probability: 0.9978, Random number: 0.7504
# Starting Iteration 22
# Worse Fitness but accepted. Fitness change: 0.0262, Acceptance probability: 0.9968, Random number: 0.5368
# Starting Iteration 23
# Worse Fitness but accepted. Fitness change: 0.0207, Acceptance probability: 0.9973, Random number: 0.7451
# Starting Iteration 24
# Worse Fitness but accepted. Fitness change: 0.0440, Acceptance probability: 0.9939, Random number: 0.1061
# Starting Iteration 25
# Worse Fitness but accepted. Fitness change: 0.0434, Acceptance probability: 0.9935, Random number: 0.2288
# Starting Iteration 26
# Worse Fitness but accepted. Fitness change: 0.0420, Acceptance probability: 0.9932, Random number: 0.1651
# Starting Iteration 27
# Worse Fitness but accepted. Fitness change: 0.0440, Acceptance probability: 0.9924, Random number: 0.9160
# Starting Iteration 28
# Worse Fitness but accepted. Fitness change: 0.0434, Acceptance probability: 0.9919, Random number: 0.3821
# Starting Iteration 29
# Worse Fitness but accepted. Fitness change: 0.0440, Acceptance probability: 0.9912, Random number: 0.6122
# Starting Iteration 30
# Worse Fitness but accepted. Fitness change: 0.0415, Acceptance probability: 0.9911, Random number: 0.5257
# Starting Iteration 31
# Worse Fitness but accepted. Fitness change: 0.0389, Acceptance probability: 0.9910, Random number: 0.7617
# Starting Iteration 32
# Worse Fitness but accepted. Fitness change: 0.0439, Acceptance probability: 0.9891, Random number: 0.7402
# Starting Iteration 33
# Worse Fitness but accepted. Fitness change: 0.0538, Acceptance probability: 0.9857, Random number: 0.8479
# Starting Iteration 34
# Worse Fitness but accepted. Fitness change: 0.0469, Acceptance probability: 0.9866, Random number: 0.6175
# Starting Iteration 35
# Worse Fitness but accepted. Fitness change: 0.0463, Acceptance probability: 0.9857, Random number: 0.9011
# Starting Iteration 36
# Worse Fitness but accepted. Fitness change: 0.0523, Acceptance probability: 0.9827, Random number: 0.0995
# Starting Iteration 37
# Worse Fitness but accepted. Fitness change: 0.0419, Acceptance probability: 0.9851, Random number: 0.3402
# Starting Iteration 38
# Worse Fitness and rejected. Fitness change: 0.0415, Acceptance probability: 0.9841, Random number: 0.9952
# Starting Iteration 39
# Subset already visited
# Worse Fitness but accepted. Fitness change: 0.0424, Acceptance probability: 0.9825, Random number: 0.9626
# Starting Iteration 40
# Subset already visited
# Worse Fitness but accepted. Fitness change: 0.0484, Acceptance probability: 0.9786, Random number: 0.9067
# Starting Iteration 41
# Worse Fitness but accepted. Fitness change: 0.0058, Acceptance probability: 0.9972, Random number: 0.6800
# Starting Iteration 42
# Worse Fitness but accepted. Fitness change: 0.0063, Acceptance probability: 0.9968, Random number: 0.6226
# Starting Iteration 43
# Subset already visited
# Worse Fitness but accepted. Fitness change: 0.0033, Acceptance probability: 0.9982, Random number: 0.3572
# Starting Iteration 44
# Worse Fitness but accepted. Fitness change: 0.0092, Acceptance probability: 0.9945, Random number: 0.4888
# Starting Iteration 45
# Worse Fitness but accepted. Fitness change: 0.0167, Acceptance probability: 0.9893, Random number: 0.6217
# Starting Iteration 46
# Worse Fitness but accepted. Fitness change: 0.0143, Acceptance probability: 0.9902, Random number: 0.3497
# Starting Iteration 47
# Worse Fitness but accepted. Fitness change: 0.0148, Acceptance probability: 0.9891, Random number: 0.1865
# Starting Iteration 48
# Worse Fitness but accepted. Fitness change: 0.0301, Acceptance probability: 0.9763, Random number: 0.8973
# Starting Iteration 49
# Worse Fitness but accepted. Fitness change: 0.0331, Acceptance probability: 0.9721, Random number: 0.9458
# Starting Iteration 50
# Worse Fitness but accepted. Fitness change: 0.0306, Acceptance probability: 0.9722, Random number: 0.3671
# Run 2 completed in 9.57 seconds
# Starting Run 3
# Starting Iteration 1
# Improvement in Fitness from 0.1508 to 0.1493 - New subset accepted
# Starting Iteration 2
# Worse Fitness but accepted. Fitness change: 0.0114, Acceptance probability: 0.9997, Random number: 0.2919
# Starting Iteration 3
# Worse Fitness but accepted. Fitness change: 0.0108, Acceptance probability: 0.9997, Random number: 0.5707
# Starting Iteration 4
# Worse Fitness but accepted. Fitness change: 0.0118, Acceptance probability: 0.9996, Random number: 0.0781
# Starting Iteration 5
# Worse Fitness but accepted. Fitness change: 0.0114, Acceptance probability: 0.9996, Random number: 0.8375
# Starting Iteration 6
# Worse Fitness but accepted. Fitness change: 0.0108, Acceptance probability: 0.9996, Random number: 0.7146
# Starting Iteration 7
# Worse Fitness but accepted. Fitness change: 0.0148, Acceptance probability: 0.9994, Random number: 0.5519
# Starting Iteration 8
# Worse Fitness but accepted. Fitness change: 0.0128, Acceptance probability: 0.9994, Random number: 0.7121
# Starting Iteration 9
# Worse Fitness but accepted. Fitness change: 0.0178, Acceptance probability: 0.9992, Random number: 0.9021
# Starting Iteration 10
# Worse Fitness but accepted. Fitness change: 0.0172, Acceptance probability: 0.9991, Random number: 0.2382
# Starting Iteration 11
# Worse Fitness but accepted. Fitness change: 0.0103, Acceptance probability: 0.9994, Random number: 0.1358
# Starting Iteration 12
# Worse Fitness but accepted. Fitness change: 0.0098, Acceptance probability: 0.9994, Random number: 0.3972
# Starting Iteration 13
# Improvement in Fitness from 0.1493 to 0.1289 - New subset accepted
# Starting Iteration 14
# Improvement in Fitness from 0.1289 to 0.1235 - New subset accepted
# Starting Iteration 15
# Worse Fitness but accepted. Fitness change: 0.0005, Acceptance probability: 1.0000, Random number: 0.9281
# Starting Iteration 16
# Worse Fitness but accepted. Fitness change: 0.0154, Acceptance probability: 0.9988, Random number: 0.5351
# Starting Iteration 17
# Worse Fitness but accepted. Fitness change: 0.0169, Acceptance probability: 0.9986, Random number: 0.1571
# Starting Iteration 18
# Worse Fitness but accepted. Fitness change: 0.0149, Acceptance probability: 0.9987, Random number: 0.5603
# Starting Iteration 19
# Worse Fitness but accepted. Fitness change: 0.0233, Acceptance probability: 0.9977, Random number: 0.3270
# Starting Iteration 20
# Worse Fitness but accepted. Fitness change: 0.0218, Acceptance probability: 0.9977, Random number: 0.9037
# Starting Iteration 21
# Worse Fitness but accepted. Fitness change: 0.0015, Acceptance probability: 0.9998, Random number: 0.1623
# Starting Iteration 22
# Worse Fitness but accepted. Fitness change: 0.0238, Acceptance probability: 0.9971, Random number: 0.0129
# Starting Iteration 23
# Worse Fitness but accepted. Fitness change: 0.0153, Acceptance probability: 0.9980, Random number: 0.5716
# Starting Iteration 24
# Worse Fitness but accepted. Fitness change: 0.0153, Acceptance probability: 0.9979, Random number: 0.8416
# Starting Iteration 25
# Worse Fitness but accepted. Fitness change: 0.0272, Acceptance probability: 0.9959, Random number: 0.2123
# Starting Iteration 26
# Worse Fitness but accepted. Fitness change: 0.0267, Acceptance probability: 0.9957, Random number: 0.4643
# Starting Iteration 27
# Worse Fitness but accepted. Fitness change: 0.0326, Acceptance probability: 0.9944, Random number: 0.8919
# Starting Iteration 28
# Worse Fitness but accepted. Fitness change: 0.0311, Acceptance probability: 0.9942, Random number: 0.4752
# Starting Iteration 29
# Worse Fitness but accepted. Fitness change: 0.0360, Acceptance probability: 0.9928, Random number: 0.6025
# Starting Iteration 30
# Worse Fitness but accepted. Fitness change: 0.0360, Acceptance probability: 0.9922, Random number: 0.5788
# Starting Iteration 31
# Worse Fitness but accepted. Fitness change: 0.0385, Acceptance probability: 0.9911, Random number: 0.9411
# Starting Iteration 32
# Worse Fitness but accepted. Fitness change: 0.0405, Acceptance probability: 0.9900, Random number: 0.7987
# Starting Iteration 33
# Worse Fitness but accepted. Fitness change: 0.0410, Acceptance probability: 0.9891, Random number: 0.3416
# Starting Iteration 34
# Subset already visited
# Worse Fitness but accepted. Fitness change: 0.0355, Acceptance probability: 0.9898, Random number: 0.4294
# Starting Iteration 35
# Subset already visited
# Worse Fitness but accepted. Fitness change: 0.0345, Acceptance probability: 0.9893, Random number: 0.5490
# Starting Iteration 36
# Worse Fitness but accepted. Fitness change: 0.0048, Acceptance probability: 0.9984, Random number: 0.9624
# Starting Iteration 37
# Worse Fitness but accepted. Fitness change: 0.0221, Acceptance probability: 0.9921, Random number: 0.9547
# Starting Iteration 38
# Subset already visited
# Worse Fitness but accepted. Fitness change: 0.0197, Acceptance probability: 0.9924, Random number: 0.5841
# Starting Iteration 39
# Worse Fitness but accepted. Fitness change: 0.0172, Acceptance probability: 0.9929, Random number: 0.5305
# Starting Iteration 40
# Worse Fitness but accepted. Fitness change: 0.0009, Acceptance probability: 0.9996, Random number: 0.8867
# Starting Iteration 41
# Worse Fitness but accepted. Fitness change: 0.0084, Acceptance probability: 0.9960, Random number: 0.6284
# Starting Iteration 42
# Worse Fitness but accepted. Fitness change: 0.0139, Acceptance probability: 0.9929, Random number: 0.7949
# Starting Iteration 43
# Worse Fitness but accepted. Fitness change: 0.0133, Acceptance probability: 0.9926, Random number: 0.6397
# Starting Iteration 44
# Worse Fitness but accepted. Fitness change: 0.0262, Acceptance probability: 0.9845, Random number: 0.9749
# Starting Iteration 45
# Worse Fitness but accepted. Fitness change: 0.0247, Acceptance probability: 0.9843, Random number: 0.9468
# Starting Iteration 46
# Worse Fitness but accepted. Fitness change: 0.0197, Acceptance probability: 0.9865, Random number: 0.2476
# Starting Iteration 47
# Worse Fitness but accepted. Fitness change: 0.0217, Acceptance probability: 0.9840, Random number: 0.2800
# Starting Iteration 48
# Worse Fitness but accepted. Fitness change: 0.0252, Acceptance probability: 0.9801, Random number: 0.3157
# Starting Iteration 49
# Worse Fitness but accepted. Fitness change: 0.0183, Acceptance probability: 0.9845, Random number: 0.1751
# Starting Iteration 50
# Worse Fitness but accepted. Fitness change: 0.0277, Acceptance probability: 0.9748, Random number: 0.5750
# Run 3 completed in 9.45 seconds
# Starting Run 4
# Starting Iteration 1
# Worse Fitness but accepted. Fitness change: 0.0020, Acceptance probability: 0.9999, Random number: 0.3205
# Starting Iteration 2
# Worse Fitness but accepted. Fitness change: 0.0015, Acceptance probability: 1.0000, Random number: 0.6477
# Starting Iteration 3
# Worse Fitness but accepted. Fitness change: 0.0030, Acceptance probability: 0.9999, Random number: 0.5413
# Starting Iteration 4
# Worse Fitness but accepted. Fitness change: 0.0030, Acceptance probability: 0.9999, Random number: 0.3692
# Starting Iteration 5
# Worse Fitness but accepted. Fitness change: 0.0010, Acceptance probability: 1.0000, Random number: 0.2556
# Starting Iteration 6
# Improvement in Fitness from 0.1251 to 0.1226 - New subset accepted
# Starting Iteration 7
# Worse Fitness but accepted. Fitness change: 0.0075, Acceptance probability: 0.9997, Random number: 0.6953
# Starting Iteration 8
# Worse Fitness but accepted. Fitness change: 0.0069, Acceptance probability: 0.9997, Random number: 0.9808
# Starting Iteration 9
# Worse Fitness but accepted. Fitness change: 0.0123, Acceptance probability: 0.9994, Random number: 0.9898
# Starting Iteration 10
# Worse Fitness but accepted. Fitness change: 0.0108, Acceptance probability: 0.9995, Random number: 0.7201
# Starting Iteration 11
# Worse Fitness but accepted. Fitness change: 0.0104, Acceptance probability: 0.9994, Random number: 0.3100
# Starting Iteration 12
# Worse Fitness but accepted. Fitness change: 0.0104, Acceptance probability: 0.9994, Random number: 0.3439
# Starting Iteration 13
# Worse Fitness but accepted. Fitness change: 0.0123, Acceptance probability: 0.9992, Random number: 0.2679
# Starting Iteration 14
# Worse Fitness but accepted. Fitness change: 0.0168, Acceptance probability: 0.9989, Random number: 0.0282
# Starting Iteration 15
# Worse Fitness but accepted. Fitness change: 0.0311, Acceptance probability: 0.9977, Random number: 0.9228
# Starting Iteration 16
# Worse Fitness but accepted. Fitness change: 0.0321, Acceptance probability: 0.9975, Random number: 0.8068
# Starting Iteration 17
# Worse Fitness but accepted. Fitness change: 0.0325, Acceptance probability: 0.9973, Random number: 0.6078
# Starting Iteration 18
# Worse Fitness but accepted. Fitness change: 0.0311, Acceptance probability: 0.9972, Random number: 0.9313
# Starting Iteration 19
# Subset already visited
# Worse Fitness but accepted. Fitness change: 0.0291, Acceptance probability: 0.9972, Random number: 0.9562
# Starting Iteration 20
# Worse Fitness but accepted. Fitness change: 0.0276, Acceptance probability: 0.9971, Random number: 0.0002
# Starting Iteration 21
# Worse Fitness but accepted. Fitness change: 0.0281, Acceptance probability: 0.9968, Random number: 0.6060
# Starting Iteration 22
# Subset already visited
# Worse Fitness but accepted. Fitness change: 0.0286, Acceptance probability: 0.9966, Random number: 0.2543
# Starting Iteration 23
# Worse Fitness but accepted. Fitness change: 0.0311, Acceptance probability: 0.9960, Random number: 0.2370
# Starting Iteration 24
# Worse Fitness but accepted. Fitness change: 0.0306, Acceptance probability: 0.9957, Random number: 0.5630
# Starting Iteration 25
# Worse Fitness but accepted. Fitness change: 0.0306, Acceptance probability: 0.9954, Random number: 0.7657
# Starting Iteration 26
# Worse Fitness but accepted. Fitness change: 0.0370, Acceptance probability: 0.9940, Random number: 0.1731
# Starting Iteration 27
# Worse Fitness but accepted. Fitness change: 0.0424, Acceptance probability: 0.9927, Random number: 0.1186
# Starting Iteration 28
# Worse Fitness but accepted. Fitness change: 0.0415, Acceptance probability: 0.9923, Random number: 0.8779
# Starting Iteration 29
# Worse Fitness but accepted. Fitness change: 0.0252, Acceptance probability: 0.9950, Random number: 0.1312
# Starting Iteration 30
# Worse Fitness but accepted. Fitness change: 0.0153, Acceptance probability: 0.9967, Random number: 0.7196
# Starting Iteration 31
# Worse Fitness but accepted. Fitness change: 0.0178, Acceptance probability: 0.9959, Random number: 0.7861
# Starting Iteration 32
# Worse Fitness but accepted. Fitness change: 0.0385, Acceptance probability: 0.9904, Random number: 0.3604
# Starting Iteration 33
# Worse Fitness but accepted. Fitness change: 0.0469, Acceptance probability: 0.9875, Random number: 0.7839
# Starting Iteration 34
# Worse Fitness but accepted. Fitness change: 0.0475, Acceptance probability: 0.9864, Random number: 0.7383
# Starting Iteration 35
# Worse Fitness but accepted. Fitness change: 0.0450, Acceptance probability: 0.9861, Random number: 0.8401
# Starting Iteration 36
# Worse Fitness but accepted. Fitness change: 0.0454, Acceptance probability: 0.9850, Random number: 0.5476
# Starting Iteration 37
# Worse Fitness but accepted. Fitness change: 0.0400, Acceptance probability: 0.9858, Random number: 0.3913
# Starting Iteration 38
# Subset already visited
# Worse Fitness but accepted. Fitness change: 0.0227, Acceptance probability: 0.9913, Random number: 0.8517
# Starting Iteration 39
# Worse Fitness but accepted. Fitness change: 0.0138, Acceptance probability: 0.9943, Random number: 0.8863
# Starting Iteration 40
# Worse Fitness but accepted. Fitness change: 0.0063, Acceptance probability: 0.9972, Random number: 0.7469
# Starting Iteration 41
# Improvement in Fitness from 0.1226 to 0.1156 - New subset accepted
# Starting Iteration 42
# Worse Fitness but accepted. Fitness change: 0.0287, Acceptance probability: 0.9853, Random number: 0.9610
# Starting Iteration 43
# Worse Fitness and rejected. Fitness change: 0.0287, Acceptance probability: 0.9842, Random number: 0.9843
# Starting Iteration 44
# Worse Fitness but accepted. Fitness change: 0.0332, Acceptance probability: 0.9804, Random number: 0.2560
# Starting Iteration 45
# Worse Fitness but accepted. Fitness change: 0.0377, Acceptance probability: 0.9761, Random number: 0.4142
# Starting Iteration 46
# Subset already visited
# Worse Fitness but accepted. Fitness change: 0.0372, Acceptance probability: 0.9747, Random number: 0.8533
# Starting Iteration 47
# Worse Fitness and rejected. Fitness change: 0.0481, Acceptance probability: 0.9650, Random number: 0.9901
# Starting Iteration 48
# Worse Fitness but accepted. Fitness change: 0.0377, Acceptance probability: 0.9704, Random number: 0.2242
# Starting Iteration 49
# Worse Fitness but accepted. Fitness change: 0.0383, Acceptance probability: 0.9677, Random number: 0.0284
# Starting Iteration 50
# Worse Fitness but accepted. Fitness change: 0.0348, Acceptance probability: 0.9684, Random number: 0.1560
# Run 4 completed in 10.92 seconds
# Starting Run 5
# Starting Iteration 1
# Improvement in Fitness from 0.1330 to 0.1324 - New subset accepted
# Starting Iteration 2
# Worse Fitness but accepted. Fitness change: 0.0024, Acceptance probability: 0.9999, Random number: 0.3924
# Starting Iteration 3
# Worse Fitness but accepted. Fitness change: 0.0049, Acceptance probability: 0.9999, Random number: 0.0804
# Starting Iteration 4
# Worse Fitness but accepted. Fitness change: 0.0019, Acceptance probability: 0.9999, Random number: 0.4385
# Starting Iteration 5
# Worse Fitness but accepted. Fitness change: 0.0054, Acceptance probability: 0.9998, Random number: 0.6220
# Starting Iteration 6
# Worse Fitness but accepted. Fitness change: 0.0054, Acceptance probability: 0.9998, Random number: 0.2859
# Starting Iteration 7
# Subset already visited
# Improvement in Fitness from 0.1324 to 0.1319 - New subset accepted
# Starting Iteration 8
# Worse Fitness but accepted. Fitness change: 0.0252, Acceptance probability: 0.9989, Random number: 0.1683
# Starting Iteration 9
# Worse Fitness but accepted. Fitness change: 0.0317, Acceptance probability: 0.9985, Random number: 0.7556
# Starting Iteration 10
# Worse Fitness but accepted. Fitness change: 0.0050, Acceptance probability: 0.9997, Random number: 0.9382
# Starting Iteration 11
# Worse Fitness but accepted. Fitness change: 0.0124, Acceptance probability: 0.9993, Random number: 0.6776
# Starting Iteration 12
# Worse Fitness but accepted. Fitness change: 0.0129, Acceptance probability: 0.9992, Random number: 0.3332
# Starting Iteration 13
# Worse Fitness but accepted. Fitness change: 0.0134, Acceptance probability: 0.9992, Random number: 0.7954
# Starting Iteration 14
# Worse Fitness but accepted. Fitness change: 0.0342, Acceptance probability: 0.9977, Random number: 0.6422
# Starting Iteration 15
# Worse Fitness but accepted. Fitness change: 0.0337, Acceptance probability: 0.9976, Random number: 0.1018
# Starting Iteration 16
# Worse Fitness but accepted. Fitness change: 0.0347, Acceptance probability: 0.9973, Random number: 0.8836
# Starting Iteration 17
# Worse Fitness but accepted. Fitness change: 0.0352, Acceptance probability: 0.9970, Random number: 0.4981
# Starting Iteration 18
# Worse Fitness but accepted. Fitness change: 0.0342, Acceptance probability: 0.9969, Random number: 0.3500
# Starting Iteration 19
# Worse Fitness but accepted. Fitness change: 0.0337, Acceptance probability: 0.9967, Random number: 0.0612
# Starting Iteration 20
# Worse Fitness but accepted. Fitness change: 0.0337, Acceptance probability: 0.9965, Random number: 0.8073
# Starting Iteration 21
# Worse Fitness but accepted. Fitness change: 0.0288, Acceptance probability: 0.9968, Random number: 0.4448
# Starting Iteration 22
# Worse Fitness but accepted. Fitness change: 0.0317, Acceptance probability: 0.9962, Random number: 0.5215
# Starting Iteration 23
# Worse Fitness but accepted. Fitness change: 0.0313, Acceptance probability: 0.9959, Random number: 0.6326
# Starting Iteration 24
# Worse Fitness but accepted. Fitness change: 0.0045, Acceptance probability: 0.9994, Random number: 0.5128
# Starting Iteration 25
# Worse Fitness but accepted. Fitness change: 0.0170, Acceptance probability: 0.9975, Random number: 0.8362
# Starting Iteration 26
# Worse Fitness but accepted. Fitness change: 0.0100, Acceptance probability: 0.9984, Random number: 0.2739
# Starting Iteration 27
# Worse Fitness but accepted. Fitness change: 0.0106, Acceptance probability: 0.9982, Random number: 0.7264
# Starting Iteration 28
# Worse Fitness but accepted. Fitness change: 0.0100, Acceptance probability: 0.9981, Random number: 0.9697
# Starting Iteration 29
# Worse Fitness but accepted. Fitness change: 0.0085, Acceptance probability: 0.9983, Random number: 0.0517
# Starting Iteration 30
# Worse Fitness but accepted. Fitness change: 0.0080, Acceptance probability: 0.9983, Random number: 0.4490
# Starting Iteration 31
# Worse Fitness but accepted. Fitness change: 0.0055, Acceptance probability: 0.9987, Random number: 0.8959
# Starting Iteration 32
# Worse Fitness but accepted. Fitness change: 0.0149, Acceptance probability: 0.9963, Random number: 0.8091
# Starting Iteration 33
# Worse Fitness but accepted. Fitness change: 0.0154, Acceptance probability: 0.9959, Random number: 0.1804
# Starting Iteration 34
# Worse Fitness but accepted. Fitness change: 0.0159, Acceptance probability: 0.9954, Random number: 0.8743
# Starting Iteration 35
# Worse Fitness but accepted. Fitness change: 0.0125, Acceptance probability: 0.9961, Random number: 0.8481
# Starting Iteration 36
# Worse Fitness but accepted. Fitness change: 0.0110, Acceptance probability: 0.9963, Random number: 0.4780
# Starting Iteration 37
# Worse Fitness but accepted. Fitness change: 0.0189, Acceptance probability: 0.9932, Random number: 0.0886
# Starting Iteration 38
# Worse Fitness but accepted. Fitness change: 0.0199, Acceptance probability: 0.9923, Random number: 0.4771
# Starting Iteration 39
# Worse Fitness but accepted. Fitness change: 0.0224, Acceptance probability: 0.9907, Random number: 0.5329
# Starting Iteration 40
# Worse Fitness but accepted. Fitness change: 0.0234, Acceptance probability: 0.9896, Random number: 0.6192
# Starting Iteration 41
# Worse Fitness but accepted. Fitness change: 0.0229, Acceptance probability: 0.9891, Random number: 0.5426
# Starting Iteration 42
# Worse Fitness but accepted. Fitness change: 0.0224, Acceptance probability: 0.9885, Random number: 0.8168
# Starting Iteration 43
# Worse Fitness but accepted. Fitness change: 0.0106, Acceptance probability: 0.9942, Random number: 0.3307
# Starting Iteration 44
# Worse Fitness but accepted. Fitness change: 0.0175, Acceptance probability: 0.9896, Random number: 0.8340
# Starting Iteration 45
# Worse Fitness but accepted. Fitness change: 0.0180, Acceptance probability: 0.9885, Random number: 0.1514
# Starting Iteration 46
# Improvement in Fitness from 0.1319 to 0.1287 - New subset accepted
# Starting Iteration 47
# Worse Fitness but accepted. Fitness change: 0.0040, Acceptance probability: 0.9971, Random number: 0.3240
# Starting Iteration 48
# Worse Fitness but accepted. Fitness change: 0.0119, Acceptance probability: 0.9906, Random number: 0.2472
# Starting Iteration 49
# Worse Fitness but accepted. Fitness change: 0.0104, Acceptance probability: 0.9912, Random number: 0.7185
# Starting Iteration 50
# Worse Fitness but accepted. Fitness change: 0.0098, Acceptance probability: 0.9910, Random number: 0.2521
# Run 5 completed in 11.24 seconds
# Starting Run 6
# Starting Iteration 1
# Worse Fitness but accepted. Fitness change: 0.0000, Acceptance probability: 1.0000, Random number: 0.4270
# Starting Iteration 2
# Worse Fitness but accepted. Fitness change: 0.0005, Acceptance probability: 1.0000, Random number: 0.8082
# Starting Iteration 3
# Worse Fitness but accepted. Fitness change: 0.0030, Acceptance probability: 0.9999, Random number: 0.2677
# Starting Iteration 4
# Worse Fitness but accepted. Fitness change: 0.0026, Acceptance probability: 0.9999, Random number: 0.1012
# Starting Iteration 5
# Worse Fitness but accepted. Fitness change: 0.0006, Acceptance probability: 1.0000, Random number: 0.7196
# Starting Iteration 6
# Improvement in Fitness from 0.1389 to 0.1380 - New subset accepted
# Starting Iteration 7
# Subset already visited
# Worse Fitness but accepted. Fitness change: 0.0015, Acceptance probability: 0.9999, Random number: 0.0418
# Starting Iteration 8
# Worse Fitness but accepted. Fitness change: 0.0045, Acceptance probability: 0.9998, Random number: 0.5915
# Starting Iteration 9
# Improvement in Fitness from 0.1380 to 0.1296 - New subset accepted
# Starting Iteration 10
# Worse Fitness but accepted. Fitness change: 0.0005, Acceptance probability: 1.0000, Random number: 0.7069
# Starting Iteration 11
# Worse Fitness but accepted. Fitness change: 0.0010, Acceptance probability: 0.9999, Random number: 0.5173
# Starting Iteration 12
# Worse Fitness but accepted. Fitness change: 0.0059, Acceptance probability: 0.9997, Random number: 0.6093
# Starting Iteration 13
# Worse Fitness but accepted. Fitness change: 0.0065, Acceptance probability: 0.9996, Random number: 0.6176
# Starting Iteration 14
# Worse Fitness but accepted. Fitness change: 0.0065, Acceptance probability: 0.9996, Random number: 0.8908
# Starting Iteration 15
# Worse Fitness but accepted. Fitness change: 0.0025, Acceptance probability: 0.9998, Random number: 0.8519
# Starting Iteration 16
# Worse Fitness but accepted. Fitness change: 0.0060, Acceptance probability: 0.9995, Random number: 0.6222
# Starting Iteration 17
# Worse Fitness but accepted. Fitness change: 0.0055, Acceptance probability: 0.9995, Random number: 0.5394
# Starting Iteration 18
# Subset already visited
# Worse Fitness but accepted. Fitness change: 0.0061, Acceptance probability: 0.9995, Random number: 0.8502
# Starting Iteration 19
# Worse Fitness but accepted. Fitness change: 0.0066, Acceptance probability: 0.9994, Random number: 0.5144
# Starting Iteration 20
# Worse Fitness but accepted. Fitness change: 0.0061, Acceptance probability: 0.9994, Random number: 0.3260
# Starting Iteration 21
# Worse Fitness but accepted. Fitness change: 0.0061, Acceptance probability: 0.9993, Random number: 0.0882
# Starting Iteration 22
# Subset already visited
# Worse Fitness but accepted. Fitness change: 0.0055, Acceptance probability: 0.9993, Random number: 0.7762
# Starting Iteration 23
# Worse Fitness but accepted. Fitness change: 0.0061, Acceptance probability: 0.9992, Random number: 0.6850
# Starting Iteration 24
# Worse Fitness but accepted. Fitness change: 0.0061, Acceptance probability: 0.9992, Random number: 0.6509
# Starting Iteration 25
# Worse Fitness but accepted. Fitness change: 0.0066, Acceptance probability: 0.9990, Random number: 0.1063
# Starting Iteration 26
# Subset already visited
# Worse Fitness but accepted. Fitness change: 0.0061, Acceptance probability: 0.9990, Random number: 0.1249
# Starting Iteration 27
# Worse Fitness but accepted. Fitness change: 0.0278, Acceptance probability: 0.9952, Random number: 0.7742
# Starting Iteration 28
# Worse Fitness but accepted. Fitness change: 0.0283, Acceptance probability: 0.9947, Random number: 0.7346
# Starting Iteration 29
# Worse Fitness but accepted. Fitness change: 0.0288, Acceptance probability: 0.9942, Random number: 0.2863
# Starting Iteration 30
# Worse Fitness but accepted. Fitness change: 0.0283, Acceptance probability: 0.9939, Random number: 0.6506
# Starting Iteration 31
# Worse Fitness but accepted. Fitness change: 0.0278, Acceptance probability: 0.9936, Random number: 0.5196
# Starting Iteration 32
# Worse Fitness but accepted. Fitness change: 0.0268, Acceptance probability: 0.9933, Random number: 0.5159
# Starting Iteration 33
# Worse Fitness but accepted. Fitness change: 0.0011, Acceptance probability: 0.9997, Random number: 0.1131
# Starting Iteration 34
# Improvement in Fitness from 0.1296 to 0.1287 - New subset accepted
# Starting Iteration 35
# Worse Fitness but accepted. Fitness change: 0.0158, Acceptance probability: 0.9951, Random number: 0.1117
# Starting Iteration 36
# Worse Fitness but accepted. Fitness change: 0.0139, Acceptance probability: 0.9954, Random number: 0.1225
# Starting Iteration 37
# Worse Fitness but accepted. Fitness change: 0.0104, Acceptance probability: 0.9963, Random number: 0.4006
# Starting Iteration 38
# Improvement in Fitness from 0.1287 to 0.1281 - New subset accepted
# Starting Iteration 39
# Worse Fitness but accepted. Fitness change: 0.0020, Acceptance probability: 0.9992, Random number: 0.4651
# Starting Iteration 40
# Worse Fitness but accepted. Fitness change: 0.0054, Acceptance probability: 0.9976, Random number: 0.6334
# Starting Iteration 41
# Worse Fitness but accepted. Fitness change: 0.0089, Acceptance probability: 0.9957, Random number: 0.1232
# Starting Iteration 42
# Worse Fitness but accepted. Fitness change: 0.0059, Acceptance probability: 0.9969, Random number: 0.3308
# Starting Iteration 43
# Worse Fitness but accepted. Fitness change: 0.0054, Acceptance probability: 0.9970, Random number: 0.9248
# Starting Iteration 44
# Worse Fitness but accepted. Fitness change: 0.0049, Acceptance probability: 0.9971, Random number: 0.0666
# Starting Iteration 45
# Worse Fitness but accepted. Fitness change: 0.0059, Acceptance probability: 0.9962, Random number: 0.8100
# Starting Iteration 46
# Worse Fitness but accepted. Fitness change: 0.0054, Acceptance probability: 0.9963, Random number: 0.1857
# Starting Iteration 47
# Worse Fitness but accepted. Fitness change: 0.0108, Acceptance probability: 0.9920, Random number: 0.6513
# Starting Iteration 48
# Worse Fitness but accepted. Fitness change: 0.0366, Acceptance probability: 0.9713, Random number: 0.6305
# Starting Iteration 49
# Worse Fitness but accepted. Fitness change: 0.0108, Acceptance probability: 0.9908, Random number: 0.5419
# Starting Iteration 50
# Worse Fitness but accepted. Fitness change: 0.0114, Acceptance probability: 0.9896, Random number: 0.1077
# Run 6 completed in 13.85 seconds
# Starting Run 7
# Starting Iteration 1
# Improvement in Fitness from 0.1557 to 0.1483 - New subset accepted
# Starting Iteration 2
# Worse Fitness but accepted. Fitness change: 0.0005, Acceptance probability: 1.0000, Random number: 0.5344
# Starting Iteration 3
# Worse Fitness but accepted. Fitness change: 0.0011, Acceptance probability: 1.0000, Random number: 0.3110
# Starting Iteration 4
# Worse Fitness but accepted. Fitness change: 0.0036, Acceptance probability: 0.9999, Random number: 0.2229
# Starting Iteration 5
# Worse Fitness but accepted. Fitness change: 0.0031, Acceptance probability: 0.9999, Random number: 0.4518
# Starting Iteration 6
# Worse Fitness but accepted. Fitness change: 0.0086, Acceptance probability: 0.9997, Random number: 0.4358
# Starting Iteration 7
# Worse Fitness but accepted. Fitness change: 0.0096, Acceptance probability: 0.9996, Random number: 0.1787
# Starting Iteration 8
# Worse Fitness but accepted. Fitness change: 0.0086, Acceptance probability: 0.9996, Random number: 0.6106
# Starting Iteration 9
# Worse Fitness but accepted. Fitness change: 0.0076, Acceptance probability: 0.9996, Random number: 0.5490
# Starting Iteration 10
# Worse Fitness but accepted. Fitness change: 0.0100, Acceptance probability: 0.9995, Random number: 0.4042
# Starting Iteration 11
# Subset already visited
# Worse Fitness but accepted. Fitness change: 0.0189, Acceptance probability: 0.9990, Random number: 0.0032
# Starting Iteration 12
# Worse Fitness but accepted. Fitness change: 0.0164, Acceptance probability: 0.9990, Random number: 0.4681
# Starting Iteration 13
# Worse Fitness but accepted. Fitness change: 0.0179, Acceptance probability: 0.9989, Random number: 0.3246
# Starting Iteration 14
# Worse Fitness but accepted. Fitness change: 0.0175, Acceptance probability: 0.9988, Random number: 0.2956
# Starting Iteration 15
# Worse Fitness but accepted. Fitness change: 0.0195, Acceptance probability: 0.9986, Random number: 0.5230
# Starting Iteration 16
# Worse Fitness but accepted. Fitness change: 0.0284, Acceptance probability: 0.9978, Random number: 0.0875
# Starting Iteration 17
# Worse Fitness but accepted. Fitness change: 0.0195, Acceptance probability: 0.9984, Random number: 0.4042
# Starting Iteration 18
# Worse Fitness but accepted. Fitness change: 0.0224, Acceptance probability: 0.9980, Random number: 0.1744
# Starting Iteration 19
# Worse Fitness but accepted. Fitness change: 0.0199, Acceptance probability: 0.9981, Random number: 0.0863
# Starting Iteration 20
# Worse Fitness but accepted. Fitness change: 0.0194, Acceptance probability: 0.9980, Random number: 0.6513
# Starting Iteration 21
# Improvement in Fitness from 0.1483 to 0.1311 - New subset accepted
# Starting Iteration 22
# Improvement in Fitness from 0.1311 to 0.1285 - New subset accepted
# Starting Iteration 23
# Subset already visited
# Worse Fitness but accepted. Fitness change: 0.0005, Acceptance probability: 0.9999, Random number: 0.8510
# Starting Iteration 24
# Worse Fitness but accepted. Fitness change: 0.0005, Acceptance probability: 0.9999, Random number: 0.8796
# Starting Iteration 25
# Worse Fitness but accepted. Fitness change: 0.0001, Acceptance probability: 1.0000, Random number: 0.6911
# Starting Iteration 26
# Improvement in Fitness from 0.1285 to 0.1281 - New subset accepted
# Starting Iteration 27
# Worse Fitness but accepted. Fitness change: 0.0000, Acceptance probability: 1.0000, Random number: 0.0190
# Starting Iteration 28
# Worse Fitness but accepted. Fitness change: 0.0020, Acceptance probability: 0.9996, Random number: 0.7651
# Starting Iteration 29
# Improvement in Fitness from 0.1281 to 0.1271 - New subset accepted
# Starting Iteration 30
# Worse Fitness but accepted. Fitness change: 0.0005, Acceptance probability: 0.9999, Random number: 0.6225
# Starting Iteration 31
# Worse Fitness but accepted. Fitness change: 0.0252, Acceptance probability: 0.9942, Random number: 0.8713
# Starting Iteration 32
# Worse Fitness but accepted. Fitness change: 0.0197, Acceptance probability: 0.9951, Random number: 0.3105
# Starting Iteration 33
# Worse Fitness but accepted. Fitness change: 0.0400, Acceptance probability: 0.9893, Random number: 0.7344
# Starting Iteration 34
# Worse Fitness but accepted. Fitness change: 0.0182, Acceptance probability: 0.9948, Random number: 0.6908
# Starting Iteration 35
# Improvement in Fitness from 0.1271 to 0.1216 - New subset accepted
# Starting Iteration 36
# Worse Fitness but accepted. Fitness change: 0.0232, Acceptance probability: 0.9923, Random number: 0.0598
# Starting Iteration 37
# Worse Fitness but accepted. Fitness change: 0.0173, Acceptance probability: 0.9938, Random number: 0.0932
# Starting Iteration 38
# Worse Fitness but accepted. Fitness change: 0.0213, Acceptance probability: 0.9918, Random number: 0.6274
# Starting Iteration 39
# Worse Fitness but accepted. Fitness change: 0.0094, Acceptance probability: 0.9961, Random number: 0.2371
# Starting Iteration 40
# Worse Fitness but accepted. Fitness change: 0.0059, Acceptance probability: 0.9974, Random number: 0.4641
# Starting Iteration 41
# Worse Fitness but accepted. Fitness change: 0.0346, Acceptance probability: 0.9835, Random number: 0.2055
# Starting Iteration 42
# Worse Fitness but accepted. Fitness change: 0.0341, Acceptance probability: 0.9826, Random number: 0.3759
# Starting Iteration 43
# Worse Fitness but accepted. Fitness change: 0.0291, Acceptance probability: 0.9840, Random number: 0.1270
# Starting Iteration 44
# Worse Fitness but accepted. Fitness change: 0.0345, Acceptance probability: 0.9796, Random number: 0.2521
# Starting Iteration 45
# Worse Fitness but accepted. Fitness change: 0.0380, Acceptance probability: 0.9759, Random number: 0.7071
# Starting Iteration 46
# Worse Fitness but accepted. Fitness change: 0.0375, Acceptance probability: 0.9745, Random number: 0.2455
# Starting Iteration 47
# Worse Fitness but accepted. Fitness change: 0.0395, Acceptance probability: 0.9712, Random number: 0.4343
# Starting Iteration 48
# Worse Fitness but accepted. Fitness change: 0.0127, Acceptance probability: 0.9899, Random number: 0.1596
# Starting Iteration 49
# Worse Fitness but accepted. Fitness change: 0.0340, Acceptance probability: 0.9713, Random number: 0.9084
# Starting Iteration 50
# Worse Fitness but accepted. Fitness change: 0.0335, Acceptance probability: 0.9696, Random number: 0.1156
# Run 7 completed in 11.09 seconds
# Starting Run 8
# Starting Iteration 1
# Worse Fitness but accepted. Fitness change: 0.0000, Acceptance probability: 1.0000, Random number: 0.3521
# Starting Iteration 2
# Improvement in Fitness from 0.1498 to 0.1493 - New subset accepted
# Starting Iteration 3
# Worse Fitness but accepted. Fitness change: 0.0000, Acceptance probability: 1.0000, Random number: 0.2050
# Starting Iteration 4
# Improvement in Fitness from 0.1493 to 0.1334 - New subset accepted
# Starting Iteration 5
# Improvement in Fitness from 0.1334 to 0.1330 - New subset accepted
# Starting Iteration 6
# Worse Fitness but accepted. Fitness change: 0.0005, Acceptance probability: 1.0000, Random number: 0.9700
# Starting Iteration 7
# Worse Fitness but accepted. Fitness change: 0.0010, Acceptance probability: 1.0000, Random number: 0.5242
# Starting Iteration 8
# Worse Fitness but accepted. Fitness change: 0.0055, Acceptance probability: 0.9998, Random number: 0.0071
# Starting Iteration 9
# Worse Fitness but accepted. Fitness change: 0.0040, Acceptance probability: 0.9998, Random number: 0.6653
# Starting Iteration 10
# Worse Fitness but accepted. Fitness change: 0.0090, Acceptance probability: 0.9995, Random number: 0.8303
# Starting Iteration 11
# Worse Fitness but accepted. Fitness change: 0.0228, Acceptance probability: 0.9988, Random number: 0.2166
# Starting Iteration 12
# Worse Fitness but accepted. Fitness change: 0.0228, Acceptance probability: 0.9987, Random number: 0.4736
# Starting Iteration 13
# Worse Fitness but accepted. Fitness change: 0.0258, Acceptance probability: 0.9984, Random number: 0.6652
# Starting Iteration 14
# Worse Fitness but accepted. Fitness change: 0.0288, Acceptance probability: 0.9981, Random number: 0.2287
# Starting Iteration 15
# Worse Fitness but accepted. Fitness change: 0.0213, Acceptance probability: 0.9985, Random number: 0.0258
# Starting Iteration 16
# Worse Fitness but accepted. Fitness change: 0.0218, Acceptance probability: 0.9983, Random number: 0.4835
# Starting Iteration 17
# Worse Fitness but accepted. Fitness change: 0.0213, Acceptance probability: 0.9982, Random number: 0.5507
# Starting Iteration 18
# Subset already visited
# Worse Fitness but accepted. Fitness change: 0.0188, Acceptance probability: 0.9983, Random number: 0.1487
# Starting Iteration 19
# Worse Fitness but accepted. Fitness change: 0.0119, Acceptance probability: 0.9988, Random number: 0.5772
# Starting Iteration 20
# Worse Fitness but accepted. Fitness change: 0.0238, Acceptance probability: 0.9975, Random number: 0.6716
# Starting Iteration 21
# Worse Fitness but accepted. Fitness change: 0.0273, Acceptance probability: 0.9969, Random number: 0.9954
# Starting Iteration 22
# Worse Fitness but accepted. Fitness change: 0.0366, Acceptance probability: 0.9956, Random number: 0.7744
# Starting Iteration 23
# Worse Fitness but accepted. Fitness change: 0.0168, Acceptance probability: 0.9978, Random number: 0.0926
# Starting Iteration 24
# Worse Fitness but accepted. Fitness change: 0.0183, Acceptance probability: 0.9974, Random number: 0.1164
# Starting Iteration 25
# Worse Fitness but accepted. Fitness change: 0.0188, Acceptance probability: 0.9972, Random number: 0.8076
# Starting Iteration 26
# Worse Fitness but accepted. Fitness change: 0.0218, Acceptance probability: 0.9965, Random number: 0.2885
# Starting Iteration 27
# Worse Fitness but accepted. Fitness change: 0.0213, Acceptance probability: 0.9963, Random number: 0.3966
# Starting Iteration 28
# Worse Fitness but accepted. Fitness change: 0.0034, Acceptance probability: 0.9994, Random number: 0.0078
# Starting Iteration 29
# Worse Fitness but accepted. Fitness change: 0.0069, Acceptance probability: 0.9986, Random number: 0.0526
# Starting Iteration 30
# ...
# Starting Iteration 33
# Worse Fitness but accepted. Fitness change: 0.0024, Acceptance probability: 0.9994, Random number: 0.9317
# Starting Iteration 34
# Worse Fitness but accepted. Fitness change: 0.0029, Acceptance probability: 0.9992, Random number: 0.1329
# Starting Iteration 35
# Improvement in Fitness from 0.1330 to 0.1285 - New subset accepted
# Starting Iteration 36
# Improvement in Fitness from 0.1285 to 0.1265 - New subset accepted
# Starting Iteration 37
# Worse Fitness but accepted. Fitness change: 0.0163, Acceptance probability: 0.9942, Random number: 0.7123
# Starting Iteration 38
# Worse Fitness but accepted. Fitness change: 0.0178, Acceptance probability: 0.9932, Random number: 0.2279
# Starting Iteration 39
# Worse Fitness but accepted. Fitness change: 0.0192, Acceptance probability: 0.9921, Random number: 0.4382
# Starting Iteration 40
# Worse Fitness but accepted. Fitness change: 0.0103, Acceptance probability: 0.9954, Random number: 0.3706
# Starting Iteration 41
# Worse Fitness but accepted. Fitness change: 0.0108, Acceptance probability: 0.9948, Random number: 0.1823
# Starting Iteration 42
# Worse Fitness but accepted. Fitness change: 0.0113, Acceptance probability: 0.9942, Random number: 0.6933
# Starting Iteration 43
# Subset already visited
# Worse Fitness but accepted. Fitness change: 0.0098, Acceptance probability: 0.9946, Random number: 0.7948
# Starting Iteration 44
# Worse Fitness but accepted. Fitness change: 0.0054, Acceptance probability: 0.9968, Random number: 0.9830
# Starting Iteration 45
# Improvement in Fitness from 0.1265 to 0.1264 - New subset accepted
# Starting Iteration 46
# Worse Fitness but accepted. Fitness change: 0.0054, Acceptance probability: 0.9963, Random number: 0.3599
# Starting Iteration 47
# Worse Fitness but accepted. Fitness change: 0.0232, Acceptance probability: 0.9829, Random number: 0.8044
# Starting Iteration 48
# Worse Fitness but accepted. Fitness change: 0.0228, Acceptance probability: 0.9820, Random number: 0.6814
# Starting Iteration 49
# Worse Fitness but accepted. Fitness change: 0.0139, Acceptance probability: 0.9882, Random number: 0.7845
# Starting Iteration 50
# Worse Fitness but accepted. Fitness change: 0.0218, Acceptance probability: 0.9801, Random number: 0.8369
# Run 8 completed in 10.84 seconds
# Starting Run 9
# Starting Iteration 1
# Improvement in Fitness from 0.1617 to 0.1553 - New subset accepted
# Starting Iteration 2
# Improvement in Fitness from 0.1553 to 0.1523 - New subset accepted
# Starting Iteration 3
# Improvement in Fitness from 0.1523 to 0.1439 - New subset accepted
# Starting Iteration 4
# Improvement in Fitness from 0.1439 to 0.1434 - New subset accepted
# Starting Iteration 5
# Worse Fitness but accepted. Fitness change: 0.0005, Acceptance probability: 1.0000, Random number: 0.4699
# Starting Iteration 6
# Worse Fitness but accepted. Fitness change: 0.0183, Acceptance probability: 0.9993, Random number: 0.7055
# Starting Iteration 7
# Worse Fitness but accepted. Fitness change: 0.0173, Acceptance probability: 0.9993, Random number: 0.1223
# Starting Iteration 8
# Worse Fitness but accepted. Fitness change: 0.0034, Acceptance probability: 0.9998, Random number: 0.2697
# Starting Iteration 9
# Improvement in Fitness from 0.1434 to 0.1409 - New subset accepted
# Starting Iteration 10
# Improvement in Fitness from 0.1409 to 0.1394 - New subset accepted
# Starting Iteration 11
# Worse Fitness but accepted. Fitness change: 0.0044, Acceptance probability: 0.9998, Random number: 0.9427
# Starting Iteration 12
# Worse Fitness but accepted. Fitness change: 0.0019, Acceptance probability: 0.9999, Random number: 0.7586
# Starting Iteration 13
# Worse Fitness but accepted. Fitness change: 0.0024, Acceptance probability: 0.9999, Random number: 0.9751
# Starting Iteration 14
# Worse Fitness but accepted. Fitness change: 0.0009, Acceptance probability: 0.9999, Random number: 0.1875
# Starting Iteration 15
# Worse Fitness but accepted. Fitness change: 0.0009, Acceptance probability: 0.9999, Random number: 0.3088
# Starting Iteration 16
# Improvement in Fitness from 0.1394 to 0.1384 - New subset accepted
# Starting Iteration 17
# Worse Fitness but accepted. Fitness change: 0.0015, Acceptance probability: 0.9999, Random number: 0.2752
# Starting Iteration 18
# Worse Fitness but accepted. Fitness change: 0.0025, Acceptance probability: 0.9998, Random number: 0.7457
# Starting Iteration 19
# Worse Fitness but accepted. Fitness change: 0.0030, Acceptance probability: 0.9997, Random number: 0.9494
# Starting Iteration 20
# Worse Fitness but accepted. Fitness change: 0.0060, Acceptance probability: 0.9994, Random number: 0.4612
# Starting Iteration 21
# Worse Fitness but accepted. Fitness change: 0.0036, Acceptance probability: 0.9996, Random number: 0.0339
# Starting Iteration 22
# Worse Fitness but accepted. Fitness change: 0.0030, Acceptance probability: 0.9996, Random number: 0.8100
# Starting Iteration 23
# Improvement in Fitness from 0.1384 to 0.1276 - New subset accepted
# Starting Iteration 24
# Worse Fitness but accepted. Fitness change: 0.0005, Acceptance probability: 0.9999, Random number: 0.5824
# Starting Iteration 25
# Worse Fitness but accepted. Fitness change: 0.0149, Acceptance probability: 0.9978, Random number: 0.5293
# Starting Iteration 26
# Worse Fitness but accepted. Fitness change: 0.0153, Acceptance probability: 0.9975, Random number: 0.8865
# Starting Iteration 27
# Worse Fitness but accepted. Fitness change: 0.0158, Acceptance probability: 0.9973, Random number: 0.4066
# Starting Iteration 28
# Improvement in Fitness from 0.1276 to 0.1256 - New subset accepted
# Starting Iteration 29
# Improvement in Fitness from 0.1256 to 0.1251 - New subset accepted
# Starting Iteration 30
# Improvement in Fitness from 0.1251 to 0.1221 - New subset accepted
# Starting Iteration 31
# Improvement in Fitness from 0.1221 to 0.1211 - New subset accepted
# Starting Iteration 32
# Worse Fitness but accepted. Fitness change: 0.0163, Acceptance probability: 0.9959, Random number: 0.2611
# Starting Iteration 33
# Worse Fitness but accepted. Fitness change: 0.0123, Acceptance probability: 0.9967, Random number: 0.3107
# Starting Iteration 34
# Worse Fitness but accepted. Fitness change: 0.0118, Acceptance probability: 0.9966, Random number: 0.8096
# Starting Iteration 35
# Worse Fitness but accepted. Fitness change: 0.0138, Acceptance probability: 0.9957, Random number: 0.3168
# Starting Iteration 36
# Worse Fitness but accepted. Fitness change: 0.0143, Acceptance probability: 0.9953, Random number: 0.5754
# Starting Iteration 37
# Worse Fitness but accepted. Fitness change: 0.0127, Acceptance probability: 0.9954, Random number: 0.1724
# Starting Iteration 38
# Worse Fitness but accepted. Fitness change: 0.0152, Acceptance probability: 0.9942, Random number: 0.8289
# Starting Iteration 39
# Worse Fitness but accepted. Fitness change: 0.0162, Acceptance probability: 0.9933, Random number: 0.4755
# Starting Iteration 40
# Worse Fitness but accepted. Fitness change: 0.0176, Acceptance probability: 0.9922, Random number: 0.0705
# Starting Iteration 41
# Worse Fitness but accepted. Fitness change: 0.0171, Acceptance probability: 0.9918, Random number: 0.6943
# Starting Iteration 42
# Worse Fitness but accepted. Fitness change: 0.0379, Acceptance probability: 0.9806, Random number: 0.5967
# Starting Iteration 43
# Worse Fitness but accepted. Fitness change: 0.0414, Acceptance probability: 0.9773, Random number: 0.9482
# Starting Iteration 44
# Worse Fitness but accepted. Fitness change: 0.0444, Acceptance probability: 0.9739, Random number: 0.4828
# Starting Iteration 45
# Worse Fitness but accepted. Fitness change: 0.0493, Acceptance probability: 0.9689, Random number: 0.4601
# Starting Iteration 46
# Worse Fitness but accepted. Fitness change: 0.0439, Acceptance probability: 0.9702, Random number: 0.9402
# Starting Iteration 47
# Worse Fitness but accepted. Fitness change: 0.0498, Acceptance probability: 0.9637, Random number: 0.7087
# Starting Iteration 48
# Worse Fitness but accepted. Fitness change: 0.0503, Acceptance probability: 0.9607, Random number: 0.1176
# Starting Iteration 49
# Worse Fitness but accepted. Fitness change: 0.0438, Acceptance probability: 0.9631, Random number: 0.5790
# Starting Iteration 50
# Worse Fitness but accepted. Fitness change: 0.0424, Acceptance probability: 0.9617, Random number: 0.5946
# Run 9 completed in 10.39 seconds
# Starting Run 10
# Starting Iteration 1
# Improvement in Fitness from 0.1439 to 0.1394 - New subset accepted
# Starting Iteration 2
# Improvement in Fitness from 0.1394 to 0.1384 - New subset accepted
# Starting Iteration 3
# Worse Fitness but accepted. Fitness change: 0.0297, Acceptance probability: 0.9991, Random number: 0.3552
# Starting Iteration 4
# Worse Fitness but accepted. Fitness change: 0.0312, Acceptance probability: 0.9990, Random number: 0.2413
# Starting Iteration 5
# Worse Fitness but accepted. Fitness change: 0.0302, Acceptance probability: 0.9989, Random number: 0.8886
# Starting Iteration 6
# Worse Fitness but accepted. Fitness change: 0.0297, Acceptance probability: 0.9989, Random number: 0.0434
# Starting Iteration 7
# Subset already visited
# Worse Fitness but accepted. Fitness change: 0.0297, Acceptance probability: 0.9988, Random number: 0.8016
# Starting Iteration 8
# Worse Fitness but accepted. Fitness change: 0.0164, Acceptance probability: 0.9993, Random number: 0.6691
# Starting Iteration 9
# Worse Fitness but accepted. Fitness change: 0.0179, Acceptance probability: 0.9992, Random number: 0.5353
# Starting Iteration 10
# Worse Fitness but accepted. Fitness change: 0.0065, Acceptance probability: 0.9997, Random number: 0.0774
# Starting Iteration 11
# Worse Fitness but accepted. Fitness change: 0.0059, Acceptance probability: 0.9997, Random number: 0.3540
# Starting Iteration 12
# Worse Fitness but accepted. Fitness change: 0.0064, Acceptance probability: 0.9996, Random number: 0.3093
# Starting Iteration 13
# Worse Fitness but accepted. Fitness change: 0.0069, Acceptance probability: 0.9996, Random number: 0.0811
# Starting Iteration 14
# Subset already visited
# Worse Fitness but accepted. Fitness change: 0.0065, Acceptance probability: 0.9996, Random number: 0.1845
# Starting Iteration 15
# Worse Fitness but accepted. Fitness change: 0.0159, Acceptance probability: 0.9988, Random number: 0.7468
# Starting Iteration 16
# Worse Fitness but accepted. Fitness change: 0.0154, Acceptance probability: 0.9988, Random number: 0.5749
# Starting Iteration 17
# Worse Fitness but accepted. Fitness change: 0.0080, Acceptance probability: 0.9993, Random number: 0.9164
# Starting Iteration 18
# Worse Fitness but accepted. Fitness change: 0.0035, Acceptance probability: 0.9997, Random number: 0.9749
# Starting Iteration 19
# Worse Fitness but accepted. Fitness change: 0.0069, Acceptance probability: 0.9993, Random number: 0.5017
# Starting Iteration 20
# Worse Fitness but accepted. Fitness change: 0.0074, Acceptance probability: 0.9992, Random number: 0.4227
# Starting Iteration 21
# Worse Fitness but accepted. Fitness change: 0.0094, Acceptance probability: 0.9989, Random number: 0.6822
# Starting Iteration 22
# Worse Fitness but accepted. Fitness change: 0.0089, Acceptance probability: 0.9989, Random number: 0.4970
# Starting Iteration 23
# Worse Fitness but accepted. Fitness change: 0.0050, Acceptance probability: 0.9994, Random number: 0.6215
# Starting Iteration 24
# Improvement in Fitness from 0.1384 to 0.1315 - New subset accepted
# Starting Iteration 25
# Worse Fitness but accepted. Fitness change: 0.0005, Acceptance probability: 0.9999, Random number: 0.7252
# Starting Iteration 26
# Improvement in Fitness from 0.1315 to 0.1315 - New subset accepted
# Starting Iteration 27
# Worse Fitness but accepted. Fitness change: 0.0198, Acceptance probability: 0.9966, Random number: 0.2003
# Starting Iteration 28
# Worse Fitness but accepted. Fitness change: 0.0188, Acceptance probability: 0.9965, Random number: 0.0741
# Starting Iteration 29
# Improvement in Fitness from 0.1315 to 0.1280 - New subset accepted
# Starting Iteration 30
# Improvement in Fitness from 0.1280 to 0.1191 - New subset accepted
# Starting Iteration 31
# Improvement in Fitness from 0.1191 to 0.1186 - New subset accepted
# Starting Iteration 32
# Worse Fitness but accepted. Fitness change: 0.0010, Acceptance probability: 0.9998, Random number: 0.4034
# Starting Iteration 33
# Worse Fitness but accepted. Fitness change: 0.0133, Acceptance probability: 0.9964, Random number: 0.8998
# Starting Iteration 34
# Worse Fitness but accepted. Fitness change: 0.0193, Acceptance probability: 0.9945, Random number: 0.6728
# Starting Iteration 35
# Worse Fitness but accepted. Fitness change: 0.0371, Acceptance probability: 0.9886, Random number: 0.1837
# Starting Iteration 36
# Worse Fitness but accepted. Fitness change: 0.0361, Acceptance probability: 0.9880, Random number: 0.1785
# Starting Iteration 37
# Worse Fitness but accepted. Fitness change: 0.0366, Acceptance probability: 0.9869, Random number: 0.9680
# Starting Iteration 38
# Worse Fitness but accepted. Fitness change: 0.0352, Acceptance probability: 0.9865, Random number: 0.8135
# Starting Iteration 39
# Worse Fitness but accepted. Fitness change: 0.0332, Acceptance probability: 0.9863, Random number: 0.6370
# Starting Iteration 40
# Worse Fitness but accepted. Fitness change: 0.0436, Acceptance probability: 0.9808, Random number: 0.5212
# Starting Iteration 41
# Worse Fitness but accepted. Fitness change: 0.0440, Acceptance probability: 0.9791, Random number: 0.3569
# Starting Iteration 42
# Worse Fitness but accepted. Fitness change: 0.0446, Acceptance probability: 0.9773, Random number: 0.7603
# Starting Iteration 43
# Worse Fitness but accepted. Fitness change: 0.0525, Acceptance probability: 0.9713, Random number: 0.5478
# Starting Iteration 44
# Worse Fitness but accepted. Fitness change: 0.0530, Acceptance probability: 0.9689, Random number: 0.9076
# Starting Iteration 45
# Worse Fitness but accepted. Fitness change: 0.0455, Acceptance probability: 0.9712, Random number: 0.4984
# Starting Iteration 46
# Worse Fitness but accepted. Fitness change: 0.0000, Acceptance probability: 1.0000, Random number: 0.0633
# Starting Iteration 47
# Worse Fitness but accepted. Fitness change: 0.0005, Acceptance probability: 0.9996, Random number: 0.6388
# Starting Iteration 48
# Worse Fitness but accepted. Fitness change: 0.0010, Acceptance probability: 0.9992, Random number: 0.7759
# Starting Iteration 49
# Subset already visited
# Worse Fitness but accepted. Fitness change: 0.0055, Acceptance probability: 0.9953, Random number: 0.5977
# Starting Iteration 50
# Worse Fitness but accepted. Fitness change: 0.0100, Acceptance probability: 0.9909, Random number: 0.6587
# Run 10 completed in 10.97 seconds
# Average run time over 10 runs: 11.43 seconds
# Standard deviation of run time: 1.89 seconds
#
# Average Metrics over all runs:
# error_rate: 0.118
# accuracy: 0.882
# precision: 0.720
# recall: 0.306
# f1: 0.428
# auc_score: 0.692
#
# Standard Deviation of Metrics over all runs:
# error_rate: 0.005
# accuracy: 0.005
# precision: 0.041
# recall: 0.023
# f1: 0.026
# auc_score: 0.018
#
# Best Metrics from each run:
# Run 1:
#   error_rate: 0.109
#   accuracy: 0.891
#   precision: 0.778
#   recall: 0.347
#   f1: 0.479
#   auc_score: 0.739
# Run 2:
#   error_rate: 0.116
#   accuracy: 0.884
#   precision: 0.725
#   recall: 0.322
#   f1: 0.444
#   auc_score: 0.702
# Run 3:
#   error_rate: 0.121
#   accuracy: 0.879
#   precision: 0.715
#   recall: 0.273
#   f1: 0.394
#   auc_score: 0.680
# Run 4:
#   error_rate: 0.113
#   accuracy: 0.887
#   precision: 0.794
#   recall: 0.291
#   f1: 0.426
#   auc_score: 0.676
# Run 5:
#   error_rate: 0.122
#   accuracy: 0.878
#   precision: 0.695
#   recall: 0.281
#   f1: 0.398
#   auc_score: 0.684
# Run 6:
#   error_rate: 0.122
#   accuracy: 0.878
#   precision: 0.664
#   recall: 0.318
#   f1: 0.429
#   auc_score: 0.697
# Run 7:
#   error_rate: 0.118
#   accuracy: 0.882
#   precision: 0.694
#   recall: 0.327
#   f1: 0.444
#   auc_score: 0.683
# Run 8:
#   error_rate: 0.125
#   accuracy: 0.875
#   precision: 0.665
#   recall: 0.279
#   f1: 0.391
#   auc_score: 0.679
# Run 9:
#   error_rate: 0.117
#   accuracy: 0.883
#   precision: 0.732
#   recall: 0.308
#   f1: 0.433
#   auc_score: 0.686
# Run 10:
#   error_rate: 0.115
#   accuracy: 0.885
#   precision: 0.733
#   recall: 0.318
#   f1: 0.443
#   auc_score: 0.695
#
# Average number of features selected over 10 runs: 8.90

# %%
results
